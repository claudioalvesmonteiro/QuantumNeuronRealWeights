# %%
import pandas as pd
import numpy as np
from extrafunctions import *
from classical_neuron import runNeuron

# %%
df = pd.read_csv('dataset.csv')
x_train = df.iloc[:, :-1].to_numpy()
y_train = df.iloc[:, -1].to_numpy()

data_len = len(y_train)
input_dim = x_train.shape[-1]
nb_epochs = 20
lr = 0.01

# print("100 epocas, pesos reais")
# runNeuron (nb_epochs=100, binaryWeights=False)

# print("100 epocas, pesos binarizados deterministicamente")
# runNeuron (nb_epochs=100, binaryWeights=True, stochastic=False)

print("100 epocas, pesos binarizados estocasticamente")
runNeuron (nb_epochs=100, binaryWeights=True, stochastic=True)
# Out:
# 100 epocas, pesos binarizados estocasticamente
# Epoch 1 accuracy: 55.00
# Epoch 2 accuracy: 69.29
# Epoch 3 accuracy: 78.57
# Epoch 4 accuracy: 85.00
# Epoch 5 accuracy: 90.00
# Epoch 6 accuracy: 90.71
# Epoch 7 accuracy: 92.86
# Epoch 8 accuracy: 94.29
# Epoch 9 accuracy: 94.29
# Epoch 10 accuracy: 94.29
# Epoch 11 accuracy: 96.43
# Epoch 12 accuracy: 97.86
# Epoch 13 accuracy: 98.57
# Epoch 14 accuracy: 98.57
# Epoch 15 accuracy: 98.57
# Epoch 16 accuracy: 98.57
# Epoch 17 accuracy: 98.57
# Epoch 18 accuracy: 98.57
# Epoch 19 accuracy: 98.57
# Epoch 20 accuracy: 98.57
# Epoch 21 accuracy: 98.57
# Epoch 22 accuracy: 98.57
# Epoch 23 accuracy: 98.57
# Epoch 24 accuracy: 98.57
# Epoch 25 accuracy: 98.57
# Epoch 26 accuracy: 98.57
# Epoch 27 accuracy: 98.57
# Epoch 28 accuracy: 98.57
# Epoch 29 accuracy: 98.57
# Epoch 30 accuracy: 98.57
# Epoch 31 accuracy: 98.57
# Epoch 32 accuracy: 98.57
# Epoch 33 accuracy: 98.57
# Epoch 34 accuracy: 98.57
# Epoch 35 accuracy: 98.57
# Epoch 36 accuracy: 98.57
# Epoch 37 accuracy: 98.57
# Epoch 38 accuracy: 98.57
# Epoch 39 accuracy: 98.57
# Epoch 40 accuracy: 98.57
# Epoch 41 accuracy: 98.57
# Epoch 42 accuracy: 98.57
# Epoch 43 accuracy: 98.57
# Epoch 44 accuracy: 98.57
# Epoch 45 accuracy: 98.57
# Epoch 46 accuracy: 98.57
# Epoch 47 accuracy: 98.57
# Epoch 48 accuracy: 98.57
# Epoch 49 accuracy: 98.57
# Epoch 50 accuracy: 98.57
# Epoch 51 accuracy: 98.57
# Epoch 52 accuracy: 98.57
# Epoch 53 accuracy: 98.57
# Epoch 54 accuracy: 98.57
# Epoch 55 accuracy: 98.57
# Epoch 56 accuracy: 98.57
# Epoch 57 accuracy: 98.57
# Epoch 58 accuracy: 98.57
# Epoch 59 accuracy: 98.57
# Epoch 60 accuracy: 98.57
# Epoch 61 accuracy: 98.57
# Epoch 62 accuracy: 98.57
# Epoch 63 accuracy: 98.57
# Epoch 64 accuracy: 98.57
# Epoch 65 accuracy: 98.57
# Epoch 66 accuracy: 98.57
# Epoch 67 accuracy: 98.57
# Epoch 68 accuracy: 98.57
# Epoch 69 accuracy: 98.57
# Epoch 70 accuracy: 98.57
# Epoch 71 accuracy: 98.57
# Epoch 72 accuracy: 98.57
# Epoch 73 accuracy: 98.57
# Epoch 74 accuracy: 98.57
# Epoch 75 accuracy: 98.57
# Epoch 76 accuracy: 98.57
# Epoch 77 accuracy: 98.57
# Epoch 78 accuracy: 98.57
# Epoch 79 accuracy: 98.57
# Epoch 80 accuracy: 98.57
# Epoch 81 accuracy: 98.57
# Epoch 82 accuracy: 98.57
# Epoch 83 accuracy: 98.57
# Epoch 84 accuracy: 98.57
# Epoch 85 accuracy: 98.57
# Epoch 86 accuracy: 98.57
# Epoch 87 accuracy: 98.57
# Epoch 88 accuracy: 98.57
# Epoch 89 accuracy: 98.57
# Epoch 90 accuracy: 98.57
# Epoch 91 accuracy: 98.57
# Epoch 92 accuracy: 98.57
# Epoch 93 accuracy: 98.57
# Epoch 94 accuracy: 98.57
# Epoch 95 accuracy: 98.57
# Epoch 96 accuracy: 98.57
# Epoch 97 accuracy: 98.57
# Epoch 98 accuracy: 98.57
# Epoch 99 accuracy: 98.57
# Epoch 100 accuracy: 98.57
